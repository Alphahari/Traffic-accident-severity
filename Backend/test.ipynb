# %%
import pickle
import pandas as pd

# %%
with open('./models/lg_classifier.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
# 0	0	2	4	1	119	0	0	1	0	8	40	2	1
data = ['0','0', '2', '4', '1', '119', '0', '0', '1', '0', '8', '40', '2', '1']
newDataFrame = pd.DataFrame(data = [data], columns=['1st_Road_Class', 'Day_of_Week', 'Junction_Control', 'Junction_Detail', 'Light_Conditions', 'Local_Authority_(District)', 'Pedestrian_Crossing-Human_Control', 'Pedestrian_Crossing-Physical_Facilities', 'Road_Surface_Conditions', 'Road_Type', 'Special_Conditions_at_Site', 'Speed_limit', 'Urban_or_Rural_Area', 'Weather_Conditions'])
newDataArray = newDataFrame.to_numpy()
print(model.predict(newDataArray))
# Out:
# ['Fatal']
